# %%
import numpy as np
import matplotlib.pyplot as plt
from diffcam.io import load_data

# %%
estimate = np.load('rgb_estimate.npy') 
pieces = [np.load('restimate.npy'), np.load('bestimate.npy'), np.load('gestimate.npy')]
estimate[estimate<0] = 0

# %%
plt.imshow(raw_data[:,:,0])

# %%
(raw_data[:,:,0] == raw_data[:,:,1])
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False],
#        [False, False,  True, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [ True,  True,  True, ...,  True, False,  True],
#        [ True,  True, False, ...,  True, False, False]])

# %%
from plot import plot_image
from mirflickr import postprocess
plot_image(estimate)
# Out:
# <AxesSubplot:>

# %%
plt.imshow(estimate)
# Out:
# WARNING: Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
(estimate[:,:,0] == estimate[:,:,1])
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
plt.imshow(estimate[:,:,0])

# %%
plt.imshow(estimate[:,:,1])

# %%
plt.imshow(estimate[:,:,2])

# %%
plt.imshow(pieces[2])

# %%
stdat = np.load('semi-transposed_data.npy')
stdat[stdat<0] = 0

# %%
plt.imshow(stdat[0] - stdat[1])

# %%
plt.imshow(estimate[:,:,0] - estimate[:,:,1])# - estimate[:,:,2])

# %%
plt.imshow(estimate[:,:,0] - pieces[0])

# %%
np.sum(estimate[:,:,0] == pieces[0])
# Out:
# 375981

# %%
estimate[:,:,0].size
# Out:
# 770640

# %%
pieces[0].size
# Out:
# 770640

# %%
375981/770640
# Out:
# 0.4878815010900031
